# %% [markdown]
# ![image.png](attachment:348dd6a4-afe1-4cb1-a8a6-92999f38a84f.png)

# %% [markdown]
# ![image.png](attachment:dd870034-9560-4983-86d5-2e7a0d84429b.png)

# %% [markdown]
# ![image.png](attachment:5e85a4bd-b81f-4899-8a8b-6dabb27c347a.png)

# %% [markdown]
# ![image.png](attachment:4a9643c0-afb1-40e7-bcc8-eb51166157d1.png)

# %% [markdown]
# ![image.png](attachment:944f95d3-0c5e-41e0-b1ac-83bf2a98dc9b.png)

# %% [markdown]
# ![image.png](attachment:aa8e32c5-ec29-4bf7-b7c6-374747e8505f.png)

# %% [markdown]
# ![image.png](attachment:b5be8192-c401-4259-8832-af1bfcaa8313.png)

# %% [markdown]
# ![image.png](attachment:5cd5568a-5b37-418e-9876-cf28104a1455.png)

# %% [markdown]
# ![image.png](attachment:8b2db9c6-3296-42b6-bb95-5ccc8421c432.png)

# %% [markdown]
# ![image.png](attachment:ed7d4313-d9bb-4330-babe-6f4657259d91.png)

# %% [markdown]
# ![image.png](attachment:dec3d965-2eac-41b5-b946-5452bb222ff9.png)

# %% [markdown]
# ![image.png](attachment:0df9f2b1-a02a-4462-ac00-5631a32337e2.png)

# %% [markdown]
# ![image.png](attachment:95e9b54f-f6fd-48b0-aa57-9d5188727c91.png)

# %% [markdown]
# ![image.png](attachment:8d820619-3a44-440a-ae18-5e7d9b94f479.png)

# %% [markdown]
# ## Problem

# %% [markdown]
# ![image.png](attachment:8b6a7363-fbee-4b0f-a378-2dfbacaeabd4.png)

# %% [markdown]
# ![image.png](attachment:9b9cafb8-c190-40bc-aef6-973490bcf799.png)

# %% [markdown]
# ![image.png](attachment:7293ce30-cb21-47a4-acf1-a9ff687d349e.png)

# %% [markdown]
# ![image.png](attachment:3dc52eef-340c-4c98-beca-93120af8b0fb.png)
