# %%
import pandas as pd
data=pd.read_csv(r"C:\Data\tabularData\TaxiPrice\train.csv")

# %%
data.head()
# Out:
#    trip_duration  distance_traveled  num_of_passengers    fare  tip  \
# 0          748.0               2.75                1.0   75.00   24
# 1         1187.0               3.43                1.0  105.00   24
# 2          730.0               3.12                1.0   71.25    0
# 3          671.0               5.63                3.0   90.00    0
# 4          329.0               2.09                1.0   45.00   12
#
#    miscellaneous_fees  total_fare  surge_applied
# 0               6.300     105.300              0
# 1              13.200     142.200              0
# 2              26.625      97.875              1
# 3               9.750      99.750              0
# 4              13.200      70.200              0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209673 entries, 0 to 209672
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   trip_duration       209673 non-null  float64
#  1   distance_traveled   209673 non-null  float64
#  2   num_of_passengers   209673 non-null  float64
#  3   fare                209673 non-null  float64
#  4   tip                 209673 non-null  int64
#  5   miscellaneous_fees  209673 non-null  float64
#  6   total_fare          209673 non-null  float64
#  7   surge_applied       209673 non-null  int64
# dtypes: float64(6), int64(2)
# memory usage: 12.8 MB

# %%
data.columns
# Out:
# Index(['trip_duration', 'distance_traveled', 'num_of_passengers', 'fare',
#        'tip', 'miscellaneous_fees', 'total_fare', 'surge_applied'],
#       dtype='object')

# %%
data.shape
# Out:
# (209673, 8)

# %%
data.isnull().sum()
# Out:
# trip_duration         0
# distance_traveled     0
# num_of_passengers     0
# fare                  0
# tip                   0
# miscellaneous_fees    0
# total_fare            0
# surge_applied         0
# dtype: int64

# %%
data[["trip_duration","distance_traveled"]]
# Out:
#         trip_duration  distance_traveled
# 0               748.0               2.75
# 1              1187.0               3.43
# 2               730.0               3.12
# 3               671.0               5.63
# 4               329.0               2.09
# ...               ...                ...
# 209668         1617.0               8.42
# 209669          438.0               1.29
# 209670          571.0               2.82
# 209671          491.0               2.16
# 209672         3614.0              33.72
#
# [209673 rows x 2 columns]

# %%
data.iloc[0:3,0:2]
# Out:
#    trip_duration  distance_traveled
# 0          748.0               2.75
# 1         1187.0               3.43
# 2          730.0               3.12

# %%
data[(data["fare"]<100) & (data["distance_traveled"]<5)][0:5]
# Out:
#    trip_duration  distance_traveled  num_of_passengers   fare  tip  \
# 0          748.0               2.75                1.0  75.00   24
# 2          730.0               3.12                1.0  71.25    0
# 4          329.0               2.09                1.0  45.00   12
# 5          355.0               1.74                1.0  45.00    0
# 6          453.0               2.22                1.0  52.50    0
#
#    miscellaneous_fees  total_fare  surge_applied
# 0               6.300     105.300              0
# 2              26.625      97.875              1
# 4              13.200      70.200              0
# 5              26.625      71.625              1
# 6               6.000      58.500              0

# %%
data["miscellaneous_fees1"]=data["miscellaneous_fees"].apply(lambda x:x-5)

# %%
data
# Out:
#         trip_duration  distance_traveled  num_of_passengers    fare  tip  \
# 0               748.0               2.75                1.0   75.00   24
# 1              1187.0               3.43                1.0  105.00   24
# 2               730.0               3.12                1.0   71.25    0
# 3               671.0               5.63                3.0   90.00    0
# 4               329.0               2.09                1.0   45.00   12
# ...               ...                ...                ...     ...  ...
# 209668         1617.0               8.42                1.0  150.00   47
# 209669          438.0               1.29                1.0   48.75   12
# 209670          571.0               2.82                1.0   63.75    0
# 209671          491.0               2.16                1.0   56.25    0
# 209672         3614.0              33.72                1.0  337.50    0
#
#         miscellaneous_fees  total_fare  surge_applied  miscellaneous_fees1
# ...

# %%
data["surge_applied1"]=data["surge_applied"].map({0:"False",1:"True"})

# %%
data.head()
# Out:
#    trip_duration  distance_traveled  num_of_passengers    fare  tip  \
# 0          748.0               2.75                1.0   75.00   24
# 1         1187.0               3.43                1.0  105.00   24
# 2          730.0               3.12                1.0   71.25    0
# 3          671.0               5.63                3.0   90.00    0
# 4          329.0               2.09                1.0   45.00   12
#
#    miscellaneous_fees  total_fare  surge_applied  miscellaneous_fees1  \
# 0               6.300     105.300              0                1.300
# 1              13.200     142.200              0                8.200
# 2              26.625      97.875              1               21.625
# 3               9.750      99.750              0                4.750
# 4              13.200      70.200              0                8.200
#
#   surge_applied1
# 0          False
# 1          False
# 2           True
# 3          False
# 4          False
