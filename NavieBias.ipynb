# %% [markdown]
# ![image.png](attachment:0d686bd2-cece-4cee-9e7b-25b35c8c553c.png)

# %% [markdown]
# ![image.png](attachment:144a9cc9-7141-4c62-9966-d2e9021a7668.png)

# %% [markdown]
# ![image.png](attachment:26dbdca1-ad05-4953-8f01-d386ef3a42f9.png)

# %% [markdown]
# ![image.png](attachment:d4a44539-8402-4d58-a4cc-8a338b8fd287.png)

# %% [markdown]
# ![image.png](attachment:903f5dad-10b7-4291-8686-f967c75eb11c.png)

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv(r"C:\Data\tabularData\normal_data\diabetes.csv")

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.boxplot()
# Out:
# <Axes: >

# %%
data.shape
# Out:
# (768, 9)

# %%
target=data["Outcome"]
features=data.drop("Outcome",axis=1)

# %%
from sklearn.preprocessing import StandardScaler
scl=StandardScaler()
sclData=scl.fit_transform(features.values)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(sclData,target.values,test_size=0.2,random_state=23)

# %%
from sklearn.naive_bayes import GaussianNB
model=GaussianNB()
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
pred=model.predict(x_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85       101
#            1       0.71      0.74      0.72        53
#
#     accuracy                           0.81       154
#    macro avg       0.78      0.79      0.79       154
# weighted avg       0.81      0.81      0.81       154
